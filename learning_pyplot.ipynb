# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_vals = [1,2,3,4]
y_vals = [2,2,0,2]
plt.plot(x_vals,y_vals,color='green',label="hello")
plt.plot([0,1,0,1],y_vals,color='black',label='goodbye')
plt.ylabel('some numbers')
plt.xlabel('other numbers')
plt.legend()
plt.title('hello')
plt.show()

# %%
t = np.arange(0.,5.,0.2)
plt.plot(t,t**2)
plt.show()

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig = plt.figure(figsize=(20,20))
ax = fig.subplots()
ax.plot(x, y)
ax.plot([1,2,3,4],[5,3,5,1])
ax.set_title('Simple plot')
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)
x_text = 2
y_text = 1
plt.annotate('local max at (' + str(x_text)+','+str(y_text)+')', xy=(x_text,y_text), xytext=(x_text+1,y_text+.5),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.ylim(0, 2)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.subplot()
[line] = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return [line]
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return [line]


anim = FuncAnimation(fig, animate, init_func=init,
                              frames=200, interval=20, blit=True)
anim.save('sine_wavie.gif', writer='imagemagick')

# %%
import mysql.connector
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#connect to mysql server with database baby_names
cnx = mysql.connector.connect(user='python', database='baby_names')
#create mysql cursor object
cur = cnx.cursor()

# %%
cur.execute("select * from baby where name = 'mary' and year = '1880'")
cur.fetchall()
# Out:
# [(1, 'Mary', 'F', 7065, 1880), (1274, 'Mary', 'M', 27, 1880)]

# %%
cur.fetchall()
# Out:
# [(1, 'Mary', 'F', 7065, 1880), (1274, 'Mary', 'M', 27, 1880)]

# %%
fig = plt.figure(figsize = (10,10))
plt.bar([10,12],[10,5])
# Out:
# <BarContainer object of 2 artists>

# %%
"""
A simple example of an animated plot
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

#x = np.arange(0, 2*np.pi, 0.01)
#line, = ax.plot(x, np.sin(x), lw = 3)
x = 5
y = 3
fig = plt.figure(figsize = (5,5))
graph = plt.bar(x,y)

def animate(i):
    line[1]=i
    #line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line

ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, blit=True)
ani.save('sine_waver.gif', writer='imagemagick')

# %%
def barlist(year): 
    query = "select name, frequency from baby where year = "+str(year)+" order by year desc limit 2;"
    cur.execute(query)
    data = cur.fetchall()
    x_data = [x[0] for x in data]
    y_data = [x[1] for x in data]
    return [x_data,y_data]
barlist(1880)
# Out:
# [['Mary', 'Anna'], [7065, 2604]]

# %%
cur.fetchall()
# Out:
# [(1, 2604),
#  (1, 2698),
#  (1, 3143),
#  (1, 3306),
#  (1, 3860),
#  (1, 3994),
#  (1, 4283),
#  (1, 4227),
#  (1, 4982),
#  (1, 5062),
#  (1, 5233),
#  (1, 5099),
#  (1, 5542),
#  (1, 5695),
#  (1, 5565),
#  (1, 5950),
#  (1, 5860),
#  (1, 5429),
#  (1, 5773),
#  (1, 5115),
#  (1, 6114)]

# %%
#number of frames, also number of years
n=20
#how many names to select
name_range = 2
#starting year
start_year = 1880
end_year = start_year+n-1
query = "select name from baby where year = 1880 order by year desc limit " + str(name_range) + " ;"
cur.execute(query)
names = [name[0] for name in cur.fetchall()]
frequencies = []
#frequencies[i][n] will by the number of people with name i in year n
for name in names:
    frequencies.append([])
    i = names.index(name)
    query = "select frequency from baby where name = '"+ name + "' and sex = 'f' and year between "+str(start_year)+" and " +str(end_year)+";"
    cur.execute(query)
    frequencies[i] += [frequency[0] for frequency in cur.fetchall()]
print(frequencies)
print(frequencies[0][15])
print(len(frequencies))
print(len(frequencies[0]))
# Out:
# [[7065, 6919, 8148, 8012, 9217, 9128, 9889, 9888, 11754, 11648, 12078, 11703, 13172, 12784, 13151, 13446, 13811, 13413, 14406, 13172], [2604, 2698, 3143, 3306, 3860, 3994, 4283, 4227, 4982, 5062, 5233, 5099, 5542, 5695, 5565, 5950, 5860, 5429, 5773, 5115]]
# 13446
# 2
# 20

# %%
import mysql.connector
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#connect to mysql server with database baby_names
cnx = mysql.connector.connect(user='python', database='baby_names')
#create mysql cursor object
cur = cnx.cursor()

# %%
#new animation program with fixed names
#number of frames, also number of years
#how many names to select
name_range = 5
#starting year
start_year = 1880
end_year = 2018
num_frames = end_year - start_year + 1
#end_year = start_year+num_frames-1
print(end_year - start_year)
query = "select name from baby where year = 1880 order by year desc limit " + str(name_range) + " ;"
cur.execute(query)
names = [name[0] for name in cur.fetchall()]
frequencies = []
#frequencies[i][n] will by the number of people with name i in year n
for name in names:
    frequencies.append([])
    i = names.index(name)
    query = "select frequency from baby where name = '"+ name + "' and sex = 'f' and year between "+str(start_year)+" and " +str(end_year)+";"
    cur.execute(query)
    frequencies[i] += [frequency[0] for frequency in cur.fetchall()]
print(len(frequencies[0]))
fig=plt.figure(figsize = (10,10))

x_data = range(1,name_range+1)
plt.xticks(x_data, names)
#plot frequency list in start year
barcollection = plt.bar(x_data,[freq[0] for freq in frequencies])
#max_pop = max(max(frequency_list(year)) for year in range(1880,1880+n))
max_pop = max(max(freq) for freq in frequencies)
plt.ylim(top=max_pop)

def animate(n):
    if n > num_frames-1:
        n = num_frames-1
    #name frequencies in year
    y_data = [freq[n] for freq in frequencies]
    #y_data=frequency_list(i+1880)
    plt.title(str(start_year+n))
    for i, b in enumerate(barcollection):
        b.set_height(y_data[i])

anim=animation.FuncAnimation(fig,animate,repeat=False,blit=False,frames=num_frames+20,
                             interval=100)
anim.save('mymovie2.gif',writer='imagemagick')
plt.show()
# Out:
# 138
# 139

# %%
###old animation program not quite working. 

import mysql.connector
import matplotlib.pyplot as plt
from matplotlib import animation
#connect to mysql server with database baby_names
cnx = mysql.connector.connect(user='python', database='baby_names')
#create mysql cursor object
cur = cnx.cursor()
#Number of frames
n=20
#how many names to select
name_range = 10
#starting year
start_year = 1880
end_year = start_year+n
#query mysql for top "name_range" number of female names in "start_year"
query = "select name from baby where year = "+str(start_year)+" and sex = 'f' order by year desc limit "+str(name_range)+ " ;"
cur.execute(query)
#make the list of names into a normal python list of strings
names = [name[0] for name in cur.fetchall()]

#the following function makes a combination of the mysql 
#statements to find frequency of each name in a given year
#
def frequency_list(year):
    query_list = ["select name,frequency from baby where year =  "+ str(year)+" and sex = 'f' and name = '"+name +"'" for name in names]
    combined_query = " union ".join(query_list)+";"
    cur.execute(combined_query)
    return [frequency[1] for frequency in cur.fetchall()]
def barlist(year): 
    query = "select name, frequency from baby where year = "+str(year)+" order by year desc limit "+str(name_range)+ " ;"
    cur.execute(query)
    data = cur.fetchall()
    x_data = [x[0] for x in data]
    y_data = [x[1] for x in data]
    return [x_data,y_data]
    #return y_data
    #return [1/float(n*k) for k in range(1,6)]

fig=plt.figure(figsize = (10,10))

x_data = range(1,name_range+1)
plt.xticks(x_data,names)
barcollection = plt.bar(x_data,frequency_list(1880))
max_pop = max(max(frequency_list(year)) for year in range(1880,1880+n))
plt.ylim(top=max_pop)

def animate(i):
    y_data=frequency_list(i+1880)
    for i, b in enumerate(barcollection):
        b.set_height(y_data[i])

anim=animation.FuncAnimation(fig,animate,repeat=False,blit=False,frames=n,
                             interval=100)
anim.save('mymovie2.gif',writer='imagemagick')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1151                         # TODO: See if turning off blit is really necessary
# -> 1152                         anim._draw_next_frame(d, blit=False)
#    1153                         if progress_callback is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1191         self._pre_draw(framedata, blit)
# -> 1192         self._draw_frame(framedata)
#    1193         self._post_draw(framedata, blit)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1754         # func needs to return a sequence of any artists that were modified.
# -> 1755         self._drawn_artists = self._func(framedata, *self._args)
#    1756         if self._blit:
#
# <ipython-input-4-5e6935043d8c> in animate(i)
#      44 def animate(i):
# ---> 45     y_data=frequency_list(i+1880)
#      46     for i, b in enumerate(barcollection):
#
# <ipython-input-4-5e6935043d8c> in frequency_list(year)
#      22     combined_query = " union ".join(query_list)+";"
# ---> 23     cur.execute(combined_query)
#      24     return [frequency[1] for frequency in cur.fetchall()]
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#
# ~/.local/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488                                raw=raw, buffered=buffered,
# --> 489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-4-5e6935043d8c> in <module>
#      49 anim=animation.FuncAnimation(fig,animate,repeat=False,blit=False,frames=n,
#      50                              interval=100)
# ---> 51 anim.save('mymovie2.gif',writer='imagemagick')
#      52 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# ~/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in finish(self)
#     365     def finish(self):
#     366         '''Finish any processing for writing the movie.'''
# --> 367         self.cleanup()
#     368
#     369     def grab_frame(self, **savefig_kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in cleanup(self)
#     409         if self._proc.returncode:
#     410             raise subprocess.CalledProcessError(
# --> 411                 self._proc.returncode, self._proc.args, out, err)
#     412
#     413     @classmethod
#
# CalledProcessError: Command '['convert', '-size', '720x720', '-depth', '8', '-delay', '10.0', '-loop', '0', 'rgba:-', 'mymovie2.gif']' returned non-zero exit status 2.
